# %%
# %pip install pandas numpy matplotlib seaborn scikit-learn openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (2.3.4)
# Requirement already satisfied: matplotlib in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: openpyxl in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: et-xmlfile in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\jakob\ideaprojects\leetcode\datascience\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# DO NOT MODIFY OR COPY THIS CELL!! 
# Note: The only imports allowed are Python's standard library, pandas, numpy, scipy, matplotlib, seaborn and scikit-learn
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import pickle
import typing
from ast import literal_eval
import openpyxl

# %%
with open('data.json', 'r') as f:
    data = f.read()
value = literal_eval(data)

df = pd.DataFrame(value)

print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406

# %%
df = pd.read_json('data.json')
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406

# %%
df = pd.read_excel('data.xlsx',sheet_name="data")
df = df.drop(columns=['Unnamed: 0'])
print(df.head())
"""print(df.head())
print(df.corr())
sns.heatmap(df.corr())
print(df.shape)
print(df.describe())"""
print(df.iloc[3][1])
df = df[(df["Pulse"] > 115)]["Pulse"]
print(df.to_list())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 109
# {1: 117, 4: 117}
# C:\Users\jakob\AppData\Local\Temp\ipykernel_26080\3803903139.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df.iloc[3][1])
